# %%
FASTA_PATH = "simulated_sequences/augumented_sequence_size10000_length150_deletions0.1_nodeletionseq0.25.fasta"
PLOTS_DIR = "outputs/plot_sequences/"
WHOLE_DATASET_ANALYSIS = "outputs/whole_dataset_analysis"

# %%
from fundemental_classes.visualization.check_against_fasta import analyze_sequences
# Amelie explain this function please
analyze_sequences(FASTA_PATH, PLOTS_DIR)

# %%
from fundemental_classes.visualization.stats import analyze_motifs_and_deletions

analyze_motifs_and_deletions(FASTA_PATH,WHOLE_DATASET_ANALYSIS)
